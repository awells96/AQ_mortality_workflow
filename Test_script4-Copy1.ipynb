# %%
# Test script 4

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
da1 = xr.open_dataarray("/glade/work/awells/air_quality/CESM2/mortality/pm25/Global_mortality_CESM2_G6-1.5K_01_2035-2084.nc")
da2 = xr.open_dataarray("/glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_CESM2_G6-1.5K_01_2035-2084.nc")

# %%
da1.mean("samples").plot(label="MC")

# %%
da2.sum(dim=("lat", "lon")).plot()
