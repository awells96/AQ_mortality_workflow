# %%
import os
import xarray as xr

# %%
# === Processing function ===
def calculate_maximum_6month_mean(start_year, end_year, monthly_mda8):
    years = list(range(start_year, end_year + 1))

    max_vals = []

    for year in years:
        # Define window: Jan of this year to Mar of next year
        start = f"{year}-01"
        end = f"{year + 1}-03"

        # Subset to this window
        subset = monthly_mda8.sel(time=slice(start, end))

        # Compute 6-month rolling mean along time
        rolling_6m = subset.rolling(time=6, center=False).mean()

        # Find index of maximum
        max_idx = rolling_6m.argmax(dim="time")
        max_val = rolling_6m.isel(time=max_idx)

        # Expand dimensions for consistent output
        max_val = max_val.expand_dims(year=[year])

        max_vals.append(max_val)

    # Combine across years
    annual_max_6m = xr.concat(max_vals, dim="year")

    return annual_max_6m

# %% [markdown]
# ## Historical

# %%
# === Path config ===
BASE_DIR = "/glade/work/awells/air_quality/CESM/ozone/MDA8/"
SAVE_DIR = "/glade/work/awells/air_quality/CESM/ozone/OSDMA8/"
SCENARIOS = ["hist"]
ens_num = 1


# === Main loop ===
for scenario in SCENARIOS:
    print(f"Processing {scenario}")
    if scenario == "ARISE":
        dates = "20350101-20691231"
        new_dates = "2035-2068"  # Final year will not be complete due to SH Jan-Mar missing
    elif scenario == "SSP245":
        dates = "20200101-20691231"
        new_dates = "2020-2068"  # Final year will not be complete due to SH Jan-Mar missing
    elif scenario == "hist":
        dates = "19900101-20091231"
        new_dates = "1990-2008"  # Final year will not be complete due to SH Jan-Mar missing
    file_list = [f"{BASE_DIR}MDA8_CESM2_{scenario}_{ens_num:02d}_{dates}.nc"]
    OSDMA8 = []

    for file in file_list:
        if not os.path.exists(file):
            print(f"Missing: {file}")
            continue

        print(f"Reading {os.path.basename(file)}")
        monthly_mda8 = xr.open_dataarray(file)

        # Create list of years to calculate over
        start_year = int(str(monthly_mda8.time.dt.year[0].values))
        end_year = int(str(monthly_mda8.time.dt.year[-2].values))  # Take second to last year to keep final March

        annual_max_6m = calculate_maximum_6month_mean(start_year, end_year, monthly_mda8)

        OSDMA8.append(annual_max_6m)

    if OSDMA8:
        combined = xr.concat(OSDMA8, dim="year")

        out_file = f"OSDMA8_CESM2_{scenario}_{ens_num:02d}_{new_dates}.nc"
        out_path = os.path.join(SAVE_DIR, out_file)

        print(f"Saving to {out_path}")
        combined.to_netcdf(out_path)

print("All processing complete.")
# Out:
# Processing hist
# Reading MDA8_CESM2_hist_01_19900101-20091231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_hist_01_1990-2009.nc
# All processing complete.

# %% [markdown]
# ## Future Scenarios

# %%
# === Path config ===
BASE_DIR = "/glade/work/awells/air_quality/CESM/ozone/MDA8/"
SAVE_DIR = "/glade/work/awells/air_quality/CESM/ozone/OSDMA8/"
SCENARIOS = ["ARISE", "SSP245"]


# === Main loop ===
for scenario in SCENARIOS:
    for ens_num in range(1, 11):
        print(f"Processing {scenario}, Ensemble {ens_num:02d}")
        if scenario == "ARISE":
            dates = "20350101-20691231"
            new_dates = "2035-2068"  # Final year will not be complete due to SH Jan-Mar missing
        elif scenario == "SSP245":
            dates = "20200101-20691231"
            new_dates = "2020-2068"  # Final year will not be complete due to SH Jan-Mar missing
        elif scenario == "hist":
            dates = "19900101-20091231"
            new_dates = "1990-2008"  # Final year will not be complete due to SH Jan-Mar missing
        file_list = [f"{BASE_DIR}MDA8_CESM2_{scenario}_{ens_num:02d}_{dates}.nc"]
        OSDMA8 = []

        for file in file_list:
            if not os.path.exists(file):
                print(f"Missing: {file}")
                continue

            print(f"Reading {os.path.basename(file)}")
            monthly_mda8 = xr.open_dataarray(file)

            # Create list of years to calculate over
            start_year = int(str(monthly_mda8.time.dt.year[0].values))
            end_year = int(str(monthly_mda8.time.dt.year[-2].values))  # Take second to last year to keep final March

            annual_max_6m = calculate_maximum_6month_mean(start_year, end_year, monthly_mda8)

            OSDMA8.append(annual_max_6m)

        if OSDMA8:
            combined = xr.concat(OSDMA8, dim="year")

            out_file = f"OSDMA8_CESM2_{scenario}_{ens_num:02d}_{new_dates}.nc"
            out_path = os.path.join(SAVE_DIR, out_file)

            print(f"Saving to {out_path}")
            combined.to_netcdf(out_path)

print("All processing complete.")
# Out:
# Processing ARISE, Ensemble 01
# Reading MDA8_CESM2_ARISE_01_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_01_2035-2069.nc
# Processing ARISE, Ensemble 02
# Reading MDA8_CESM2_ARISE_02_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_02_2035-2069.nc
# Processing ARISE, Ensemble 03
# Reading MDA8_CESM2_ARISE_03_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_03_2035-2069.nc
# Processing ARISE, Ensemble 04
# Reading MDA8_CESM2_ARISE_04_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_04_2035-2069.nc
# Processing ARISE, Ensemble 05
# Reading MDA8_CESM2_ARISE_05_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_05_2035-2069.nc
# Processing ARISE, Ensemble 06
# Reading MDA8_CESM2_ARISE_06_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_06_2035-2069.nc
# Processing ARISE, Ensemble 07
# Reading MDA8_CESM2_ARISE_07_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_07_2035-2069.nc
# Processing ARISE, Ensemble 08
# Reading MDA8_CESM2_ARISE_08_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_08_2035-2069.nc
# Processing ARISE, Ensemble 09
# Reading MDA8_CESM2_ARISE_09_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_09_2035-2069.nc
# Processing ARISE, Ensemble 10
# Reading MDA8_CESM2_ARISE_10_20350101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_ARISE_10_2035-2069.nc
# Processing SSP245, Ensemble 01
# Reading MDA8_CESM2_SSP245_01_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_01_2020-2069.nc
# Processing SSP245, Ensemble 02
# Reading MDA8_CESM2_SSP245_02_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_02_2020-2069.nc
# Processing SSP245, Ensemble 03
# Reading MDA8_CESM2_SSP245_03_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_03_2020-2069.nc
# Processing SSP245, Ensemble 04
# Reading MDA8_CESM2_SSP245_04_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_04_2020-2069.nc
# Processing SSP245, Ensemble 05
# Reading MDA8_CESM2_SSP245_05_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_05_2020-2069.nc
# Processing SSP245, Ensemble 06
# Reading MDA8_CESM2_SSP245_06_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_06_2020-2069.nc
# Processing SSP245, Ensemble 07
# Reading MDA8_CESM2_SSP245_07_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_07_2020-2069.nc
# Processing SSP245, Ensemble 08
# Reading MDA8_CESM2_SSP245_08_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_08_2020-2069.nc
# Processing SSP245, Ensemble 09
# Reading MDA8_CESM2_SSP245_09_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_09_2020-2069.nc
# Processing SSP245, Ensemble 10
# Reading MDA8_CESM2_SSP245_10_20200101-20691231.nc
# Saving to /glade/work/awells/air_quality/CESM/ozone/OSDMA8/OSDMA8_CESM2_SSP245_10_2020-2069.nc
# All processing complete.
