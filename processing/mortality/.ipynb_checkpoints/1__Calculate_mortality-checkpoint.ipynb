# %%
# Save mortality by year and for each ensemble

# %%
import xarray as xr
import numpy as np

# %%
# === Attributal fraction ===
def att_frac(x, TMREL, beta):
    # equation is: AF = (RR - 1)/RR
    # where RR = e^(beta*(x-TMREL))
    # Akritidis et al. (2024) - unsure which reference would be best

    O3_diff = x - TMREL
    TMREL_O3 = xr.where(O3_diff > 0, O3_diff, 0)  # where the difference < 0 set to 0

    RR = np.exp(beta * TMREL_O3)
    AF = (RR - 1)/RR
    return AF


# === Mortality equation ===
def mortality(AF, bmr, pop):
    # equation is: M(x,y) = AF(x,y) * BMR_c * POP(x,y)
    # Akritidis et al. (2024) - unsure which reference would be best
    M = AF * bmr * pop
    return M


# === Latitude weighting sum ===
def weighted_sum(da):
    weights = np.cos(np.deg2rad(da.lat))
    weights.name = "weights"
    new_da = da.weighted(weights).sum(("lon", "lat"))
    return new_da

# %%
# === Path config ===
BMR_DIR = "/glade/work/awells/air_quality/BMR/"
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"
O3_DIR = "/glade/work/awells/air_quality/CESM/ozone/OSDMA8_BC/"

# %%
# === Load data ===
BMR = xr.open_dataarray(f"{BMR_DIR}GBD_BMR_Country_Mask_popgrid_COPD_1990-2009.nc")  # three quantiles
POP = xr.open_dataarray(f"{POP_DIR}ssp2_total_regrid_annual_2000-2100.nc")

# %%
# === Calculate beta for RR GBD 2021 ===

# Relative risk for 10ppb increase in OSDMA8, GBD 2021
RR_10ppb = 1.074  # [95% CI 1.014 – 1.137]
# equation is: RR = e^(beta*(x-TMREL)) where RR_10ppb = e^(10beta)
beta = np.log(RR_10ppb)/10

# TMREL from GBD 2021
TMREL = 32.4  # [95% CI 29.1 – 35.7]

# %%
# === Path config ===
SAVE_DIR = "/glade/work/awells/air_quality/CESM/mortality/"
SCENARIOS = ["ARISE", "SSP245"]

# === Main loop ===
for scenario in SCENARIOS:
    for ens_num in range(1, 11):
        print(f"Processing {scenario}, Ensemble {ens_num:02d}")
        if scenario == "ARISE":
            dates = "2035-2068"
        elif scenario == "SSP245":
            dates = "2020-2068"

        o3 = xr.open_dataarray(f"{O3_DIR}OSDMA8_BC_popgrid_CESM2_{scenario}_{ens_num:02d}_{dates}.nc")

        M = []

        for year in o3["year"].values:
            AF = att_frac(o3.sel(year=year), TMREL, beta)
            M.append(mortality(AF, BMR, POP))
            print(f"Median mortality rate for {year} is {weighted_sum(M[-1]).sel(quantile='median').round().values}")

        M_cleaned = [da.drop_vars('year', errors='ignore') for da in M]
        mortality_timeseries = xr.concat(M_cleaned, dim=(xr.DataArray(o3["year"].values, dims="year", name="year")))

        print(f"Saving mortality timeseries to {SAVE_DIR}")
        mortality_timeseries.to_netcdf(f"{SAVE_DIR}Mortality_CESM2_{scenario}_{ens_num:02d}_{dates}.nc")
# Out:
# Processing SSP245, Ensemble 01
# Median mortality rate for 2020 is 372089.0
# Median mortality rate for 2021 is 379377.0
# Median mortality rate for 2022 is 384035.0
# Median mortality rate for 2023 is 375863.0
# Median mortality rate for 2024 is 394027.0
# Median mortality rate for 2025 is 391841.0
# Median mortality rate for 2026 is 388552.0
# Median mortality rate for 2027 is 392554.0
# Median mortality rate for 2028 is 409276.0
# Median mortality rate for 2029 is 384401.0
# Median mortality rate for 2030 is 426514.0
# Median mortality rate for 2031 is 429912.0
# Median mortality rate for 2032 is 415218.0
# Median mortality rate for 2033 is 419456.0
# Median mortality rate for 2034 is 412293.0
# Median mortality rate for 2035 is 418954.0
# Median mortality rate for 2036 is 404601.0
# Median mortality rate for 2037 is 429809.0
# Median mortality rate for 2038 is 402730.0
# Median mortality rate for 2039 is 425726.0
# Median mortality rate for 2040 is 424397.0
# Median mortality rate for 2041 is 432025.0
# Median mortality rate for 2042 is 426471.0
# Median mortality rate for 2043 is 440328.0
# Median mortality rate for 2044 is 433439.0
# Median mortality rate for 2045 is 440003.0
# Median mortality rate for 2046 is 440349.0
# Median mortality rate for 2047 is 440256.0
# Median mortality rate for 2048 is 426791.0
# Median mortality rate for 2049 is 429004.0
# Median mortality rate for 2050 is 423111.0
# Median mortality rate for 2051 is 430370.0
# Median mortality rate for 2052 is 398065.0
# Median mortality rate for 2053 is 411101.0
# Median mortality rate for 2054 is 430808.0
# Median mortality rate for 2055 is 418887.0
# Median mortality rate for 2056 is 404758.0
# Median mortality rate for 2057 is 407329.0
# Median mortality rate for 2058 is 409775.0
# Median mortality rate for 2059 is 391772.0
# Median mortality rate for 2060 is 401085.0
# Median mortality rate for 2061 is 388796.0
# Median mortality rate for 2062 is 387859.0
# Median mortality rate for 2063 is 371874.0
# Median mortality rate for 2064 is 370716.0
# Median mortality rate for 2065 is 366549.0
# Median mortality rate for 2066 is 371595.0
# Median mortality rate for 2067 is 390597.0
# Median mortality rate for 2068 is 340204.0
# Median mortality rate for 2069 is 349204.0
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM/mortality/
# Saving country mortality to /glade/work/awells/air_quality/CESM/mortality/
