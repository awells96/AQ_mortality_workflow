# %%
# Calculate regional mortality - requires ~70GB memory

# %%
import os
import xarray as xr
import warnings
from utils.utils import get_scenario_config
from utils.mortality_utils import mortality

# %%
# === Health variables ===
# COPD, DIABETES, ISCHEMIC_HEART_DISEASE, LOWER_RESPIRATORY_INFECTIONS, LUNG_CANCER, STROKE
# resp_copd, t2_dm, cvd_ihd, lri, neo_lung, cvd_stroke
health_vars = ["COPD", "DIABETES", "ISCHEMIC_HEART_DISEASE",
               "LOWER_RESPIRATORY_INFECTIONS", "LUNG_CANCER", "STROKE"]

# %%
# === Path config ===
MASKS_DIR = "/glade/work/awells/air_quality/BMR/masks/region/"
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"
BMR_DIR = "/glade/derecho/scratch/awells/air_quality/BMR/"
TMREL_DIR = "/glade/derecho/scratch/awells/air_quality/TMREL/"
RR_DIR = "/glade/derecho/scratch/awells/air_quality/rr_pm25/"

# %%
# Load country masks
mask_file = "GBD_Region_Masks_0.10.nc"
mask_path = os.path.join(MASKS_DIR, mask_file)
masks = xr.open_dataarray(mask_path)

# Load population file
pop_file = "ssp2_coarse_grid_annual_2000-2100.nc"
pop_path = os.path.join(POP_DIR, pop_file)
population = xr.open_dataarray(pop_path)
pop = population.reindex_like(masks, method="nearest", tolerance=1e-9)

# %%
# === Calculate the scalar distributions ===
n_samples = 200

# TMREL from GBD21 (uniform distribution)
tmrel_file = f"TMREL_{n_samples}_samples_pm25.nc"
tmrel_path = os.path.join(TMREL_DIR, tmrel_file)
tmrel_da = xr.open_dataarray(tmrel_path)

# %%
warnings.filterwarnings('ignore')

# === Scenario and path config ===
# Set to whatever scenario and model you want
# Function returns error if not recognised
model = "CESM2"
scenario = "SSP245_G6"

config = get_scenario_config(model, scenario)
ensemble_members = config["ensemble_members"]
years = config["years"]
dates = f"{years.start}-{years.stop}"

PM25_DIR = f"/glade/work/awells/air_quality/{model}/pm25/annual_pm25_bc/"
SAVE_DIR = f"/glade/work/awells/air_quality/{model}/mortality/pm25/region/{n_samples}_samples"

for health_VAR in health_vars[4:]:
    print(f"Processing health variable {health_VAR}")

    # RR from GBD21 (normal distribution)
    rr_file = f"RR_{health_VAR}_{n_samples}_samples_pm25.nc"
    rr_path = os.path.join(RR_DIR, rr_file)
    rr_da = xr.open_dataarray(rr_path)

    del rr_file, rr_path

    # Load BMR for each grid point
    bmr_file = f"GBD_BMR_Country_Mask_{health_VAR}_{n_samples}_samples_1990-2009.nc"
    bmr_path = os.path.join(BMR_DIR, bmr_file)
    BMR = xr.open_dataarray(bmr_path)  # three quantiles

    del bmr_file, bmr_path

    for ens_num in [1]:
        print(f"Processing ensemble member {ens_num:02d}")

        # Load ozone data
        pm25_file = f"Annual_PM25_BC_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
        pm25_path = os.path.join(PM25_DIR, pm25_file)
        pm25 = xr.open_dataarray(pm25_path).astype("float32")

        # Adjust indices to match (with small tolerance)
        # e.g., max 1e-7 km distance
        pm25 = pm25.reindex_like(masks, method="nearest", tolerance=1e-9, fill_value=0)

        del pm25_file, pm25_path

        # make pm25 dask-backed
        pm25 = pm25.chunk({'lat': 180, 'lon': 360})

        for year in range(years.start, years.stop + 1):
            print(f"Processing year {year}")

            # Find RR at each grid point
            pm25_year = pm25.sel(year=year)
            RR = rr_da.interp(exposure=pm25_year)

            del pm25_year

            RR = RR.where(RR["exposure"] >= tmrel_da, 1)
            AF = (1 - (1/RR)).chunk({"samples": 10})

            del RR

            POP = pop.sel(year=year).chunk({"lat": 180, "lon": 360})

            M = mortality(AF, BMR, POP)

            del AF, POP

            for region in masks.region:
                print(f"Processing {region.data}")

                region_mask = masks.sel(region=region)
                region_M = M.where(region_mask == 1).sum(dim=("lat", "lon"))
                region_M = region_M.expand_dims(region=[region.data])

                del region_mask

                description = (f"Regional {health_VAR} mortality due to PM2.5 "
                               f"sample size {n_samples} - scripts by A.F."
                               " Wells (2025)")
                region_M.attrs["description"] = description
                region_M.attrs["model"] = model
                region_M.attrs["scenario"] = scenario
                region_M.attrs["ensemble_number"] = ens_num
                region_M.attrs["region"] = region.data
                region_M.attrs["year"] = year

                out_file = f"Regional_mortality_{health_VAR}_{n_samples}samples_{model}_{scenario}_{ens_num:02d}_{region.data}_{year}.nc"
                out_path = os.path.join(SAVE_DIR, out_file)
                print(f"Saving to {out_path}")
                region_M.to_netcdf(out_path)

                del region_M

        del pm25

    del rr_da, BMR

print("All processing complete.")
# Out:
# Processing health variable LUNG_CANCER
# Processing ensemble member 01
# Processing year 2020
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2020.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2020.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2020.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2020.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2020.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2020.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2020.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2020.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2020.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2020.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2020.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2020.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2020.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2020.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2020.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2020.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2020.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2020.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2020.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2020.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2020.nc
# Processing year 2021
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2021.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2021.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2021.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2021.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2021.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2021.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2021.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2021.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2021.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2021.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2021.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2021.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2021.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2021.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2021.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2021.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2021.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2021.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2021.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2021.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2021.nc
# Processing year 2022
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2022.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2022.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2022.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2022.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2022.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2022.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2022.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2022.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2022.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2022.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2022.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2022.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2022.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2022.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2022.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2022.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2022.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2022.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2022.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2022.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2022.nc
# Processing year 2023
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2023.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2023.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2023.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2023.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2023.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2023.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2023.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2023.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2023.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2023.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2023.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2023.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2023.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2023.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2023.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2023.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2023.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2023.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2023.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2023.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2023.nc
# Processing year 2024
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2024.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2024.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2024.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2024.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2024.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2024.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2024.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2024.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2024.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2024.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2024.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2024.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2024.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2024.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2024.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2024.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2024.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2024.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2024.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2024.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2024.nc
# Processing year 2025
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2025.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2025.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2025.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2025.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2025.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2025.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2025.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2025.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2025.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2025.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2025.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2025.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2025.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2025.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2025.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2025.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2025.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2025.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2025.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2025.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2025.nc
# Processing year 2026
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2026.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2026.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2026.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2026.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2026.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2026.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2026.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2026.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2026.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2026.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2026.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2026.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2026.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2026.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2026.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2026.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2026.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2026.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2026.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2026.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2026.nc
# Processing year 2027
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2027.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2027.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2027.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2027.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2027.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2027.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2027.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2027.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2027.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2027.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2027.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2027.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2027.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2027.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2027.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2027.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2027.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2027.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2027.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2027.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2027.nc
# Processing year 2028
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2028.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2028.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2028.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2028.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2028.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2028.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2028.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2028.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2028.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2028.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2028.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2028.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2028.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2028.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2028.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2028.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2028.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2028.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2028.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2028.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2028.nc
# Processing year 2029
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2029.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2029.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2029.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2029.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2029.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2029.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2029.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2029.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2029.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2029.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2029.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2029.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2029.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2029.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2029.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2029.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2029.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2029.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2029.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2029.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2029.nc
# Processing year 2030
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2030.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2030.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2030.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2030.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2030.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2030.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2030.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2030.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Andean Latin America_2030.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Caribbean_2030.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Latin America_2030.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2030.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2030.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_South Asia_2030.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_East Asia_2030.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Oceania_2030.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southeast Asia_2030.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2030.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2030.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2030.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2030.nc
# Processing year 2031
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Asia_2031.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Central Europe_2031.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Eastern Europe_2031.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Australasia_2031.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2031.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_High-income North America_2031.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Southern Latin America_2031.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_LUNG_CANCER_200samples_CESM2_SSP245_G6_01_Western Europe_2031.nc
# Processing Andean Latin America
# ...
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Australasia_2056.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2056.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income North America_2056.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Latin America_2056.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Europe_2056.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Andean Latin America_2056.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Caribbean_2056.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Latin America_2056.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2056.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2056.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_South Asia_2056.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_East Asia_2056.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Oceania_2056.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southeast Asia_2056.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2056.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2056.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2056.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2056.nc
# Processing year 2057
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Asia_2057.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Europe_2057.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Europe_2057.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Australasia_2057.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2057.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income North America_2057.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Latin America_2057.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Europe_2057.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Andean Latin America_2057.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Caribbean_2057.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Latin America_2057.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2057.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2057.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_South Asia_2057.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_East Asia_2057.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Oceania_2057.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southeast Asia_2057.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2057.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2057.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2057.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2057.nc
# Processing year 2058
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Asia_2058.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Europe_2058.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Europe_2058.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Australasia_2058.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2058.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income North America_2058.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Latin America_2058.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Europe_2058.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Andean Latin America_2058.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Caribbean_2058.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Latin America_2058.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2058.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2058.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_South Asia_2058.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_East Asia_2058.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Oceania_2058.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southeast Asia_2058.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2058.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2058.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2058.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2058.nc
# Processing year 2059
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Asia_2059.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Europe_2059.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Europe_2059.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Australasia_2059.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income Asia Pacific_2059.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_High-income North America_2059.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Latin America_2059.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Europe_2059.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Andean Latin America_2059.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Caribbean_2059.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Latin America_2059.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Tropical Latin America_2059.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_North Africa and Middle East_2059.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_South Asia_2059.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_East Asia_2059.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Oceania_2059.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southeast Asia_2059.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Central Sub-Saharan Africa_2059.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Eastern Sub-Saharan Africa_2059.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Southern Sub-Saharan Africa_2059.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/pm25/region/200_samples/Regional_mortality_STROKE_200samples_CESM2_SSP245_G6_01_Western Sub-Saharan Africa_2059.nc
# Processing year 2060
