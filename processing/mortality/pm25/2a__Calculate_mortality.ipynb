# %%
# Save mortality at each grid point using central estimates only

# %%
import os
import glob
import xarray as xr
from utils.mortality_utils import mortality
from utils.utils import get_scenario_config, create_global_country_map

# %%
# === Path config ===
BMR_DIR = "/glade/work/awells/air_quality/BMR/"
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"

# %%
# === Load data ===
bmr_file = "GBD_BMR_Country_COPD_newlabels_1990-2009.nc"
bmr_path = os.path.join(BMR_DIR, bmr_file)
bmr_country = xr.open_dataarray(bmr_path).sel(quantile="mean")  # central estimate
BMR = create_global_country_map(bmr_country)

pop_file = "ssp2_coarse_grid_annual_2000-2100.nc"
pop_path = os.path.join(POP_DIR, pop_file)
population = xr.open_dataarray(pop_path)
pop = population.reindex_like(BMR, method="nearest", tolerance=1e-9)

# %%
# TMREL from GBD 2021
TMREL = 4.15  # [95% Uniform CI 2.4 – 5.9]

# %%
# === Health variables ===
# COPD, DIABETES, ISCHEMIC_HEART_DISEASE, LOWER_RESPIRATORY_INFECTIONS, LUNG_CANCER, STROKE
# resp_copd, t2_dm, cvd_ihd, lri, neo_lung, cvd_stroke
health_vars = ["COPD", "DIABETES", "ISCHEMIC_HEART_DISEASE",
               "LOWER_RESPIRATORY_INFECTIONS", "LUNG_CANCER", "STROKE"]

# %%
# === Scenario and path config ===
# Set to whatever scenario and model you want
# Function returns error if not recognised
model = "CESM2"
scenario = "G6-1.5K"

config = get_scenario_config(model, scenario)
ensemble_members = config["ensemble_members"]
years = config["years"]
dates = f"{years.start}-{years.stop}"

RR_DIR = "/glade/work/awells/air_quality/GBD21/RR_curves/"
PM25_DIR = f"/glade/work/awells/air_quality/{model}/pm25/annual_pm25_bc/"
SAVE_DIR = f"/glade/work/awells/air_quality/{model}/mortality/pm25/gridpoint_mortality/"

# === Main loop ===
for health_VAR in health_vars:
    for ens_num in ensemble_members:
        print(f"Processing {scenario}, Ensemble {ens_num:02d}, {health_VAR}")

        pm25_file = f"Annual_PM25_BC_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
        pm25_path = os.path.join(PM25_DIR, pm25_file)
        pm25 = xr.open_dataarray(pm25_path)

        # Adjust indices to match (with small tolerance)
        # e.g., max 1e-7 km distance
        pm25 = pm25.reindex_like(BMR, method="nearest", tolerance=1e-9, fill_value=0)

        RR_file = f"IHME_GBD_2021_AIR_POLLUTION_1990_2021_PM_RR_{health_VAR}.nc"
        RR_path = os.path.join(RR_DIR, RR_file)
        RR_values = xr.open_dataset(RR_path)["mean"]  # central estimate

        M = []

        print(f"Processing years {years.start}-{years.stop}")
        for year in range(years.start, years.stop + 1):
            POP = pop.sel(year=year)

            # Find RR at each grid point
            RR = RR_values.interp(exposure=pm25.sel(year=year))
            RR = RR.where(RR["exposure"] >= TMREL, 1)
            AF = 1 - (1/RR)

            del RR

            mortality_year = mortality(AF, BMR, POP)
            M.append(mortality_year)

            del mortality_year, AF, POP

        M_cleaned = [da.drop_vars("year", errors="ignore") for da in M]

        del M

        mortality_timeseries = xr.concat(
            M_cleaned,
            dim=(xr.DataArray(pm25["year"].values,
                              dims="year", name="year"))
        )

        mortality_timeseries = mortality_timeseries.drop_vars(
            ["exposure", "quantile", "region"]
        )

        del M_cleaned

        description = (f"Total {health_VAR} mortality due to PM2.5 using "
                       "central estimates only - scripts "
                       "by A.F. Wells (2025)")
        mortality_timeseries.attrs["description"] = description
        mortality_timeseries.attrs["health_var"] = health_VAR
        mortality_timeseries.attrs["ensemble_number"] = ens_num
        mortality_timeseries.attrs["scenario"] = scenario
        mortality_timeseries.attrs["model"] = model

        out_file = f"Mortality_{health_VAR}_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
        out_path = os.path.join(SAVE_DIR, out_file)

        print(f"Saving mortality timeseries to {out_path}")
        mortality_timeseries.to_netcdf(out_path)

print("All processing complete.")
# Out:
# Processing G6-1.5K, Ensemble 01, COPD
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_COPD_CESM2_G6-1.5K_01_2035-2084.nc
# Processing G6-1.5K, Ensemble 02, COPD
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_COPD_CESM2_G6-1.5K_02_2035-2084.nc
# Processing G6-1.5K, Ensemble 03, COPD
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_COPD_CESM2_G6-1.5K_03_2035-2084.nc
# Processing G6-1.5K, Ensemble 01, DIABETES
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_DIABETES_CESM2_G6-1.5K_01_2035-2084.nc
# Processing G6-1.5K, Ensemble 02, DIABETES
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_DIABETES_CESM2_G6-1.5K_02_2035-2084.nc
# Processing G6-1.5K, Ensemble 03, DIABETES
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_DIABETES_CESM2_G6-1.5K_03_2035-2084.nc
# Processing G6-1.5K, Ensemble 01, ISCHEMIC_HEART_DISEASE
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_ISCHEMIC_HEART_DISEASE_CESM2_G6-1.5K_01_2035-2084.nc
# Processing G6-1.5K, Ensemble 02, ISCHEMIC_HEART_DISEASE
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_ISCHEMIC_HEART_DISEASE_CESM2_G6-1.5K_02_2035-2084.nc
# Processing G6-1.5K, Ensemble 03, ISCHEMIC_HEART_DISEASE
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_ISCHEMIC_HEART_DISEASE_CESM2_G6-1.5K_03_2035-2084.nc
# Processing G6-1.5K, Ensemble 01, LOWER_RESPIRATORY_INFECTIONS
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_LOWER_RESPIRATORY_INFECTIONS_CESM2_G6-1.5K_01_2035-2084.nc
# Processing G6-1.5K, Ensemble 02, LOWER_RESPIRATORY_INFECTIONS
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_LOWER_RESPIRATORY_INFECTIONS_CESM2_G6-1.5K_02_2035-2084.nc
# Processing G6-1.5K, Ensemble 03, LOWER_RESPIRATORY_INFECTIONS
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_LOWER_RESPIRATORY_INFECTIONS_CESM2_G6-1.5K_03_2035-2084.nc
# Processing G6-1.5K, Ensemble 01, LUNG_CANCER
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_LUNG_CANCER_CESM2_G6-1.5K_01_2035-2084.nc
# Processing G6-1.5K, Ensemble 02, LUNG_CANCER
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_LUNG_CANCER_CESM2_G6-1.5K_02_2035-2084.nc
# Processing G6-1.5K, Ensemble 03, LUNG_CANCER
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_LUNG_CANCER_CESM2_G6-1.5K_03_2035-2084.nc
# Processing G6-1.5K, Ensemble 01, STROKE
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_STROKE_CESM2_G6-1.5K_01_2035-2084.nc
# Processing G6-1.5K, Ensemble 02, STROKE
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_STROKE_CESM2_G6-1.5K_02_2035-2084.nc
# Processing G6-1.5K, Ensemble 03, STROKE
# Processing years 2035-2084
# Saving mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_STROKE_CESM2_G6-1.5K_03_2035-2084.nc
# All processing complete.

# %%
# Save the sum of all mortality outcomes

for ens_num in ensemble_members:
    # Find all files for this ensemble
    in_files = f"Mortality_*_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
    in_path = os.path.join(SAVE_DIR, in_files)
    files = sorted(glob.glob(in_path))

    # Open and combine
    datasets = [xr.open_dataarray(f) for f in files]

    # Align (important in case of slight coordinate mismatches)
    aligned = xr.align(*datasets, join="exact")

    # Sum across the health variables
    summed_da = sum(aligned)

    description = ("Total mortality due to PM2.5 using "
                   "central estimates only - scripts "
                   "by A.F. Wells (2025)")
    summed_da.attrs["description"] = description
    summed_da.attrs["ensemble_number"] = ens_num
    summed_da.attrs["scenario"] = scenario
    summed_da.attrs["model"] = model

    out_file = f"Mortality_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
    out_path = os.path.join(SAVE_DIR, out_file)

    print(f"Saving summed mortality timeseries to {out_path}")
    summed_da.to_netcdf(out_path)
    
print("All processing complete.")
# Out:
# Saving summed mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_CESM2_G6-1.5K_01_2035-2084.nc
# Saving summed mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_CESM2_G6-1.5K_02_2035-2084.nc
# Saving summed mortality timeseries to /glade/work/awells/air_quality/CESM2/mortality/pm25/gridpoint_mortality/Mortality_CESM2_G6-1.5K_03_2035-2084.nc
# All processing complete.
