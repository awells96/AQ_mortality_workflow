# %%
# Calculate regional mortality - requires >80GB memory

# %%
import os
import xarray as xr
import numpy as np
import warnings
from utils.utils import get_scenario_config
from utils.mortality_utils import att_frac

# %%
# === Path config ===
MASKS_DIR = "/glade/work/awells/air_quality/BMR/masks/region/"
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"
BMR_DIR = "/glade/derecho/scratch/awells/air_quality/BMR/"

# %%
# Load country masks
mask_file = "GBD_Region_Masks_0.10.nc"
mask_path = os.path.join(MASKS_DIR, mask_file)
masks = xr.open_dataarray(mask_path)

# Load population file
pop_file = "ssp2_coarse_grid_annual_2000-2100.nc"
pop_path = os.path.join(POP_DIR, pop_file)
population = xr.open_dataarray(pop_path)
pop = population.reindex_like(masks, method="nearest", tolerance=1e-9)

# %%
# === Calculate the scalar distributions (assuming normal dist.) ===
n_samples = 1000

# TMREL from GBD21 (uniform distribution)
tmrel_low = 29.1
tmrel_high = 35.7
tmrel_samples = np.random.uniform(tmrel_low, tmrel_high, size=n_samples)

tmrel_da = xr.DataArray(
    tmrel_samples,
    dims=['samples'],
    coords={'samples': np.arange(n_samples)}
).astype("float32")

# Beta from RR per 10ppb (normal distribution)
RR_10 = 1.074
RR_10_lower = 1.014
RR_10_upper = 1.137
beta_mean = np.log(RR_10) / 10
beta_std = (np.log(RR_10_upper) - np.log(RR_10_lower)) / (2 * 1.96 * 10)
beta_samples = np.random.normal(beta_mean, beta_std, size=n_samples)

beta_da = xr.DataArray(
    beta_samples,
    dims=['samples'],
    coords={'samples': np.arange(n_samples)}
).astype("float32")

# Load BMR for each grid point
bmr_file = f"GBD_BMR_Country_Mask_COPD_{n_samples}_samples_1990-2009.nc"
bmr_path = os.path.join(BMR_DIR, bmr_file)
BMR = xr.open_dataarray(bmr_path)  # three quantiles

# %%
warnings.filterwarnings('ignore')

# === Scenario and path config ===
# Set to whatever scenario and model you want
# Function returns error if not recognised
model = "CESM2"
scenario = "G6-1.5K"

config = get_scenario_config(model, scenario)
# ensemble_members = config["ensemble_members"][:1]
ensemble_members = [2]
years = config["years"]

O3_DIR = f"/glade/work/awells/air_quality/{model}/ozone/OSDMA8_BC/"
SAVE_DIR = f"/glade/work/awells/air_quality/{model}/mortality/ozone/region/"

for ens_num in ensemble_members:
    print(f"Processing ensemble member {ens_num:02d}")
    dates = f"{years.start}-{years.stop - 1}"

    # Load ozone data
    o3_file = f"OSDMA8_BC_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
    o3_path = os.path.join(O3_DIR, o3_file)
    o3 = xr.open_dataarray(o3_path).astype("float32")
    o3 = o3.reindex_like(masks, method="nearest", tolerance=1e-9, fill_value=0)

    del o3_file, o3_path

    # make o3 dask-backed
    o3 = o3.chunk({'lat': 180, 'lon': 360})

    # range doesn't include the final year which is okay
    # because OSDMA8 excludes final year
    for year in years:
        print(f"Processing year {year}")
        o3_year = o3.sel(year=year)
        AF = att_frac(o3_year, tmrel_da, beta_da).chunk({"samples": 10})

        POP = pop.sel(year=year).chunk({"lat": 180, "lon": 360})
        M = AF * BMR * POP

        del o3_year, AF, POP

        for region in masks.region:
            print(f"Processing {region.data}")

            region_mask = masks.sel(region=region)
            region_M = M.where(region_mask == 1).sum(dim=("lat", "lon"))
            del region_mask

            # mean over samples
            M_mean = region_M.mean(dim="samples")
            # median over samples
            M_median = region_M.quantile(0.5, dim="samples")
            # percentiles for 95% CI
            M_lower = region_M.quantile(0.025, dim="samples")
            M_upper = region_M.quantile(0.975, dim="samples")

            del region_M

            M_summary = xr.Dataset({
                "M_mean": M_mean.astype("float32").drop_vars("year"),
                "M_median": M_median.astype("float32").drop_vars("quantile"),
                "M_lower95": M_lower.astype("float32").drop_vars("quantile"),
                "M_upper95": M_upper.astype("float32").drop_vars("quantile")
            })

            del M_mean, M_median, M_lower, M_upper

            description = ("Regional mortality (COPD) due to ozone "
                           "statistics: including mean, median, "
                           "and the 95% CI - scripts by A.F. Wells (2025)")
            M_summary.attrs["description"] = description
            M_summary.attrs["model"] = model
            M_summary.attrs["scenario"] = scenario
            M_summary.attrs["ensemble_number"] = ens_num
            M_summary.attrs["region"] = region.data
            M_summary.attrs["year"] = year

            out_file = f"Regional_mortality_stats_{model}_{scenario}_{ens_num:02d}_{region.data}_{year}.nc"
            out_path = os.path.join(SAVE_DIR, out_file)
            print(f"Saving to {out_path}")
            M_summary.to_netcdf(out_path)

            del M_summary

        del M

    del o3

print("All processing complete.")
# Out:
# Processing ensemble member 02
# Processing year 2035
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2035.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2035.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2035.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2035.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2035.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2035.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2035.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2035.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2035.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2035.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2035.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2035.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2035.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2035.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2035.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2035.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2035.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2035.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2035.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2035.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2035.nc
# Processing year 2036
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2036.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2036.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2036.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2036.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2036.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2036.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2036.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2036.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2036.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2036.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2036.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2036.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2036.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2036.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2036.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2036.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2036.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2036.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2036.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2036.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2036.nc
# Processing year 2037
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2037.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2037.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2037.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2037.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2037.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2037.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2037.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2037.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2037.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2037.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2037.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2037.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2037.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2037.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2037.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2037.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2037.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2037.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2037.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2037.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2037.nc
# Processing year 2038
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2038.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2038.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2038.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2038.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2038.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2038.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2038.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2038.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2038.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2038.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2038.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2038.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2038.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2038.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2038.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2038.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2038.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2038.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2038.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2038.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2038.nc
# Processing year 2039
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2039.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2039.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2039.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2039.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2039.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2039.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2039.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2039.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2039.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2039.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2039.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2039.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2039.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2039.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2039.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2039.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2039.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2039.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2039.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2039.nc
# Processing year 2040
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2040.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2040.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2040.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2040.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2040.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2040.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2040.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2040.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2040.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2040.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2040.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2040.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2040.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2040.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2040.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2040.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2040.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2040.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2040.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2040.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2040.nc
# Processing year 2041
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2041.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2041.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2041.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2041.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2041.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2041.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2041.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2041.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2041.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2041.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2041.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2041.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2041.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2041.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2041.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2041.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2041.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2041.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2041.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2041.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2041.nc
# Processing year 2042
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2042.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2042.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2042.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2042.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2042.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2042.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2042.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2042.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2042.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2042.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2042.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2042.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2042.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2042.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2042.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2042.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2042.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2042.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2042.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2042.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2042.nc
# Processing year 2043
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2043.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2043.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2043.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2043.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2043.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2043.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2043.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2043.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2043.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2043.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2043.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2043.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2043.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2043.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2043.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2043.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2043.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2043.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2043.nc
# Processing year 2044
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2044.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2044.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2044.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2044.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2044.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2044.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2044.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2044.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2044.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2044.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2044.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2044.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2044.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2044.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2044.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2044.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2044.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2044.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2044.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2044.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2044.nc
# Processing year 2045
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2045.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2045.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2045.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2045.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2045.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2045.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2045.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2045.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2045.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2045.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2045.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2045.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2045.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2045.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2045.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2045.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2045.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2045.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2045.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2045.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2045.nc
# Processing year 2046
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2046.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2046.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2046.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2046.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2046.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2046.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2046.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2046.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2046.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2046.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2046.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2046.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2046.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2046.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2046.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2046.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2046.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2046.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2046.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2046.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2046.nc
# Processing year 2047
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2047.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2047.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2047.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2047.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2047.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2047.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2047.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2047.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2047.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2047.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2047.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2047.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2047.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2047.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2047.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2047.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2047.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2047.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2047.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2047.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2047.nc
# Processing year 2048
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2048.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2048.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2048.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2048.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2048.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2048.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2048.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2048.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2048.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2048.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2048.nc
# Processing North Africa and Middle East
# ...
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2074.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2074.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2074.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2074.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2074.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2074.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2074.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2074.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2074.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2074.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2074.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2074.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2074.nc
# Processing year 2075
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2075.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2075.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2075.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2075.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2075.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2075.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2075.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2075.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2075.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2075.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2075.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2075.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2075.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2075.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2075.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2075.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2075.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2075.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2075.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2075.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2075.nc
# Processing year 2076
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2076.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2076.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2076.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2076.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2076.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2076.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2076.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2076.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2076.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2076.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2076.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2076.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2076.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2076.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2076.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2076.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2076.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2076.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2076.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2076.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2076.nc
# Processing year 2077
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2077.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2077.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2077.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2077.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2077.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2077.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2077.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2077.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2077.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2077.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2077.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2077.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2077.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2077.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2077.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2077.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2077.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2077.nc
# Processing Eastern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Sub-Saharan Africa_2077.nc
# Processing Southern Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Sub-Saharan Africa_2077.nc
# Processing Western Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Sub-Saharan Africa_2077.nc
# Processing year 2078
# Processing Central Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Asia_2078.nc
# Processing Central Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Europe_2078.nc
# Processing Eastern Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Eastern Europe_2078.nc
# Processing Australasia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Australasia_2078.nc
# Processing High-income Asia Pacific
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income Asia Pacific_2078.nc
# Processing High-income North America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_High-income North America_2078.nc
# Processing Southern Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southern Latin America_2078.nc
# Processing Western Europe
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Western Europe_2078.nc
# Processing Andean Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Andean Latin America_2078.nc
# Processing Caribbean
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Caribbean_2078.nc
# Processing Central Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Latin America_2078.nc
# Processing Tropical Latin America
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Tropical Latin America_2078.nc
# Processing North Africa and Middle East
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_North Africa and Middle East_2078.nc
# Processing South Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_South Asia_2078.nc
# Processing East Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_East Asia_2078.nc
# Processing Oceania
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Oceania_2078.nc
# Processing Southeast Asia
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Southeast Asia_2078.nc
# Processing Central Sub-Saharan Africa
# Saving to /glade/work/awells/air_quality/CESM2/mortality/ozone/region/Regional_mortality_stats_CESM2_G6-1.5K_02_Central Sub-Saharan Africa_2078.nc
