# %%
# Calculate global mortality - requires ~15GB memory

# %%
import os
import xarray as xr
import warnings
from utils.utils import get_scenario_config
from utils.mortality_utils import att_frac

# %%
# === Path config ===
MASKS_DIR = "/glade/work/awells/air_quality/BMR/masks/country/"
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"
TMREL_DIR = "/glade/derecho/scratch/awells/air_quality/TMREL/"
BETA_DIR = "/glade/derecho/scratch/awells/air_quality/beta_ozone/"
BMR_DIR = "/glade/derecho/scratch/awells/air_quality/BMR_ozone/"

# %%
# Load country masks
mask_file = "GBD_Country_Masks_0.10.nc"
mask_path = os.path.join(MASKS_DIR, mask_file)
masks = xr.open_dataarray(mask_path)

# Load population file
pop_file = "ssp2_coarse_grid_annual_2000-2100.nc"
pop_path = os.path.join(POP_DIR, pop_file)
population = xr.open_dataarray(pop_path)
pop = population.reindex_like(masks, method="nearest", tolerance=1e-9)

# %%
# === Calculate the scalar distributions ===
n_samples = 300

# TMREL from GBD21 (uniform distribution)
tmrel_file = f"TMREL_{n_samples}_samples_ozone.nc"
tmrel_path = os.path.join(TMREL_DIR, tmrel_file)
tmrel_da = xr.open_dataarray(tmrel_path)

# Beta from RR per 10ppb (normal distribution)
beta_file = f"beta_{n_samples}_samples_ozone.nc"
beta_path = os.path.join(BETA_DIR, beta_file)
beta_da = xr.open_dataarray(beta_path)

# Load BMR for each grid point
bmr_file = f"GBD_BMR_Country_Mask_COPD_{n_samples}_samples_1990-2009.nc"
bmr_path = os.path.join(BMR_DIR, bmr_file)
BMR = xr.open_dataarray(bmr_path)  # three quantiles

# %%
warnings.filterwarnings('ignore')

# === Scenario and path config ===
# Set to whatever scenario and model you want
# Function returns error if not recognised
model = "UKESM1"
scenario = "G6-1.5K"

config = get_scenario_config(model, scenario)
ensemble_members = config["ensemble_members"]
years = config["years"]

O3_DIR = f"/glade/work/awells/air_quality/{model}/ozone/OSDMA8_BC/"
SAVE_DIR = f"/glade/work/awells/air_quality/{model}/mortality/ozone/global/{n_samples}_samples/"

for ens_num in ensemble_members:
    print(f"Processing ensemble member {ens_num:02d}")
    dates = f"{years.start}-{years.stop - 1}"

    # Load ozone data
    o3_file = f"OSDMA8_BC_{model}_{scenario}_{ens_num:02d}_{dates}.nc"
    o3_path = os.path.join(O3_DIR, o3_file)
    o3 = xr.open_dataarray(o3_path).astype("float32")
    o3 = o3.reindex_like(masks, method="nearest", tolerance=1e-9, fill_value=0)

    del o3_file, o3_path

    # make o3 dask-backed
    o3 = o3.chunk({'lat': 180, 'lon': 360})

    # range doesn't include the final year which is okay
    # because OSDMA8 excludes final year
    for year in years:
        print(f"Processing year {year}")
        o3_year = o3.sel(year=year)
        AF = att_frac(o3_year, tmrel_da, beta_da).chunk({"samples": 10})

        POP = pop.sel(year=year).chunk({"lat": 180, "lon": 360})
        M = AF * BMR * POP
        global_M = M.sum(dim=("lat", "lon"))

        del o3_year, AF, POP, M

        description = ("Global mortality (COPD) due to ozone "
                       " - scripts by A.F. Wells (2025)")
        global_M.attrs["description"] = description
        global_M.attrs["model"] = model
        global_M.attrs["scenario"] = scenario
        global_M.attrs["ensemble_number"] = ens_num
        global_M.attrs["year"] = year

        out_file = f"Global_mortality_{n_samples}samples_{model}_{scenario}_{ens_num:02d}_{year}.nc"
        out_path = os.path.join(SAVE_DIR, out_file)
        print(f"Saving to {out_path}")
        global_M.to_netcdf(out_path)

        del global_M

    del o3

print("All processing complete.")
# Out:
# Processing ensemble member 01
# Processing year 2035
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2035.nc
# Processing year 2036
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2036.nc
# Processing year 2037
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2037.nc
# Processing year 2038
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2038.nc
# Processing year 2039
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2039.nc
# Processing year 2040
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2040.nc
# Processing year 2041
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2041.nc
# Processing year 2042
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2042.nc
# Processing year 2043
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2043.nc
# Processing year 2044
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2044.nc
# Processing year 2045
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2045.nc
# Processing year 2046
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2046.nc
# Processing year 2047
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2047.nc
# Processing year 2048
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2048.nc
# Processing year 2049
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2049.nc
# Processing year 2050
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2050.nc
# Processing year 2051
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2051.nc
# Processing year 2052
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2052.nc
# Processing year 2053
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2053.nc
# Processing year 2054
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2054.nc
# Processing year 2055
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2055.nc
# Processing year 2056
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2056.nc
# Processing year 2057
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2057.nc
# Processing year 2058
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2058.nc
# Processing year 2059
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2059.nc
# Processing year 2060
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2060.nc
# Processing year 2061
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2061.nc
# Processing year 2062
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2062.nc
# Processing year 2063
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2063.nc
# Processing year 2064
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2064.nc
# Processing year 2065
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2065.nc
# Processing year 2066
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2066.nc
# Processing year 2067
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2067.nc
# Processing year 2068
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2068.nc
# Processing year 2069
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2069.nc
# Processing year 2070
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2070.nc
# Processing year 2071
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2071.nc
# Processing year 2072
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2072.nc
# Processing year 2073
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2073.nc
# Processing year 2074
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2074.nc
# Processing year 2075
# Saving to /glade/work/awells/air_quality/UKESM1/mortality/ozone/global/test/Global_mortality_300samples_UKESM1_G6-1.5K_01_2075.nc
# Processing year 2076
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 39
#      36 AF = att_frac(o3_year, tmrel_da, beta_da).chunk({"samples": 10})
#      38 POP = pop.sel(year=year).chunk({"lat": 180, "lon": 360})
# ---> 39 M = AF * BMR * POP
#      40 global_M = M.sum(dim=("lat", "lon"))
#      42 del o3_year, AF, POP, M
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/_typed_ops.py:551, in DataArrayOpsMixin.__mul__(self, other)
#     550 def __mul__(self, other: DaCompatible) -> Self | Dataset | DataTree:
# --> 551     return self._binary_op(other, operator.mul)
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/dataarray.py:4817, in DataArray._binary_op(self, other, f, reflexive)
#    4813 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4814 other_coords = getattr(other, "coords", None)
#    4816 variable = (
# -> 4817     f(self.variable, other_variable_or_arraylike)
#    4818     if not reflexive
#    4819     else f(other_variable_or_arraylike, self.variable)
#    4820 )
#    4821 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4822 name = result_name([self, other])
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/_typed_ops.py:934, in VariableOpsMixin.__mul__(self, other)
#     933 def __mul__(self, other: VarCompatible) -> Self | T_DA | Dataset | DataTree:
# --> 934     return self._binary_op(other, operator.mul)
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/variable.py:2384, in Variable._binary_op(self, other, f, reflexive)
#    2382     other_data, self_data, dims = _broadcast_compat_data(other, self)
#    2383 else:
# -> 2384     self_data, other_data, dims = _broadcast_compat_data(self, other)
#    2385 keep_attrs = _get_keep_attrs(default=False)
#    2386 attrs = self._attrs if keep_attrs else None
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/variable.py:2992, in _broadcast_compat_data(self, other)
#    2983     if (isinstance(other, Variable) and self.dims != other.dims) or (
#    2984         is_duck_array(other) and self.ndim != other.ndim
#    2985     ):
#    2986         raise ValueError(
#    2987             "Broadcasting is necessary but automatic broadcasting is disabled via "
#    2988             "global option `'arithmetic_broadcast'`. "
#    2989             "Use `xr.set_options(arithmetic_broadcast=True)` to enable automatic broadcasting."
#    2990         )
# -> 2992 if all(hasattr(other, attr) for attr in ["dims", "data", "shape", "encoding"]):
#    2993     # `other` satisfies the necessary Variable API for broadcast_variables
#    2994     new_self, new_other = _broadcast_compat_variables(self, other)
#    2995     self_data = new_self.data
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/variable.py:2992, in <genexpr>(.0)
#    2983     if (isinstance(other, Variable) and self.dims != other.dims) or (
#    2984         is_duck_array(other) and self.ndim != other.ndim
#    2985     ):
#    2986         raise ValueError(
#    2987             "Broadcasting is necessary but automatic broadcasting is disabled via "
#    2988             "global option `'arithmetic_broadcast'`. "
#    2989             "Use `xr.set_options(arithmetic_broadcast=True)` to enable automatic broadcasting."
#    2990         )
# -> 2992 if all(hasattr(other, attr) for attr in ["dims", "data", "shape", "encoding"]):
#    2993     # `other` satisfies the necessary Variable API for broadcast_variables
#    2994     new_self, new_other = _broadcast_compat_variables(self, other)
#    2995     self_data = new_self.data
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/variable.py:473, in Variable.data(self)
#     471     return self._data
#     472 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 473     return self._data.get_duck_array()
#     474 else:
#     475     return self.values
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:835, in MemoryCachedArray.get_duck_array(self)
#     834 def get_duck_array(self):
# --> 835     self._ensure_cached()
#     836     return self.array.get_duck_array()
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:832, in MemoryCachedArray._ensure_cached(self)
#     831 def _ensure_cached(self):
# --> 832     self.array = as_indexable(self.array.get_duck_array())
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:789, in CopyOnWriteArray.get_duck_array(self)
#     788 def get_duck_array(self):
# --> 789     return self.array.get_duck_array()
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:652, in LazilyIndexedArray.get_duck_array(self)
#     648     array = apply_indexer(self.array, self.key)
#     649 else:
#     650     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     651     # it may wrap a BackendArray so use its __getitem__
# --> 652     array = self.array[self.key]
#     654 # self.array[self.key] is now a numpy array when
#     655 # self.array is a BackendArray subclass
#     656 # and self.key is BasicIndexer((slice(None, None, None),))
#     657 # so we need the explicit check for ExplicitlyIndexed
#     658 if isinstance(array, ExplicitlyIndexed):
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:103, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     102 def __getitem__(self, key):
# --> 103     return indexing.explicit_indexing_adapter(
#     104         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     105     )
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:1013, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     991 """Support explicit indexing by delegating to a raw indexing method.
#     992
#     993 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1010 Indexing result, in the form of a duck numpy-array.
#    1011 """
#    1012 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1013 result = raw_indexing_method(raw_key.tuple)
#    1014 if numpy_indices.tuple:
#    1015     # index the loaded np.ndarray
#    1016     indexable = NumpyIndexingAdapter(result)
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:116, in NetCDF4ArrayWrapper._getitem(self, key)
#     114     with self.datastore.lock:
#     115         original_array = self.get_array(needs_lock=False)
# --> 116         array = getitem(original_array, key)
#     117 except IndexError as err:
#     118     # Catch IndexError in netCDF4 and return a more informative
#     119     # error message.  This is most often called when an unsorted
#     120     # indexer is used before the data is loaded from disk.
#     121     msg = (
#     122         "The indexing operation you are attempting to perform "
#     123         "is not valid on netCDF4.Variable object. Try loading "
#     124         "your data into memory first by calling .load()."
#     125     )
#
# KeyboardInterrupt:
