# %%
# Calculate OSDMA8 population weighted exposure

# %%
import xarray as xr
import os
import numpy as np

# %%
# === Latitude weighting sum ===
def weighted_sum(da):
    weights = np.cos(np.deg2rad(da.lat))
    weights.name = "weights" 
    new_da = da.weighted(weights).sum(("lon", "lat"))
    return new_da

# %%
# === Path config ===
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"
BMR_DIR = "/glade/work/awells/air_quality/BMR/"
O3_DIR = "/glade/work/awells/air_quality/CESM/ozone/OSDMA8_BC/"
SAVE_DIR = "/glade/work/awells/air_quality/CESM/ozone/exposure/"
SCENARIOS = ["ARISE", "SSP245"]


pop_ssp2 = xr.open_dataarray(f"{POP_DIR}ssp2_total_regrid_2000-2100.nc")

# Interpolate population across decades
new_year = range(2000, 2101)
new_pop = pop_ssp2.interp(year=new_year)

# === Main loop ===
for scenario in SCENARIOS:
    for ens_num in range(1, 11):
        print(f"Processing {scenario}, Ensemble {ens_num:02d}")
        # Load data array
        if scenario == "ARISE":
            dates = "2035-2069"
        elif scenario == "SSP245":
            dates = "2020-2069"

        o3 = xr.open_dataarray(f"{O3_DIR}OSDMA8_BC_popgrid_CESM2_{scenario}_{ens_num:02d}_{dates}.nc")
        population = new_pop.sel(year=o3.year)  # Select same years as o3 data for population

        weighted_value = population * o3

        global_population = weighted_sum(population)
        global_weight = weighted_sum(weighted_value)

        global_exposure = global_weight / global_population

        out_file = f"OSDMA8_global_population_weighted_exposure_CESM2_{scenario}_{ens_num:02d}_{dates}.nc"
        out_path = os.path.join(SAVE_DIR, out_file)

        print(f"Saving to {out_path}")
        global_exposure.to_netcdf(out_path)
# Out:
# Processing ARISE, Ensemble 01
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_01_2035-2069.nc
# Processing ARISE, Ensemble 02
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_02_2035-2069.nc
# Processing ARISE, Ensemble 03
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_03_2035-2069.nc
# Processing ARISE, Ensemble 04
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_04_2035-2069.nc
# Processing ARISE, Ensemble 05
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_05_2035-2069.nc
# Processing ARISE, Ensemble 06
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_06_2035-2069.nc
# Processing ARISE, Ensemble 07
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_07_2035-2069.nc
# Processing ARISE, Ensemble 08
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_08_2035-2069.nc
# Processing ARISE, Ensemble 09
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_09_2035-2069.nc
# Processing ARISE, Ensemble 10
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_ARISE_10_2035-2069.nc
# Processing SSP245, Ensemble 01
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_01_2020-2069.nc
# Processing SSP245, Ensemble 02
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_02_2020-2069.nc
# Processing SSP245, Ensemble 03
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_03_2020-2069.nc
# Processing SSP245, Ensemble 04
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_04_2020-2069.nc
# Processing SSP245, Ensemble 05
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_05_2020-2069.nc
# Processing SSP245, Ensemble 06
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_06_2020-2069.nc
# Processing SSP245, Ensemble 07
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_07_2020-2069.nc
# Processing SSP245, Ensemble 08
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_08_2020-2069.nc
# Processing SSP245, Ensemble 09
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_09_2020-2069.nc
# Processing SSP245, Ensemble 10
# Saving to /glade/work/awells/air_quality/CESM/ozone/exposure/OSDMA8_global_population_weighted_exposure_CESM2_SSP245_10_2020-2069.nc
