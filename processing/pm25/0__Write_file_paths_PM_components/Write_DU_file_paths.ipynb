# %%
# Save file list for dust - DU

# %%
import os
import re
import json
from datetime import datetime
from utils.utils import get_scenario_config

# %%
# Create a config variable to store file path information for each model/scenario
# Adjust as necessary for new data
MODEL_PATH_CONFIG = {
    # CESM2
    "CESM2": {
        "base": "/glade/campaign",
        "scenarios": {
            # SSP2-4.5
            "SSP245_G6": {
                "dir_template": (
                    "{base}/cesm/collections/CESM2-WACCM-SSP245/"
                    "b.e21.BWSSP245cmip6.f09_g17.CMIP6-SSP2-4.5-WACCM.0{ens}/"
                    "atm/proc/tseries/month_1/"
                ),
                "search_term": r"\.dst_[a-z][0-9]\.",
            },

            # Historical
            "hist": {
                "dir_template": (
                    "{base}/cesm/development/wawg/WACCM6-TSMLT-HIST/"
                    "b.e21.BWHISTcmip6.f09_g17.CMIP6-historical-WACCM.1980_2014.0{ens}/"
                    "atm/proc/tseries/month_1/"
                ),
                "search_term": r"\.dst_[a-z][0-9]\.",
            },

            # G6-1.5K-SAI
            "G6-1.5K": {
                "dir_template": (
                    "{base}/collections/rda/data/d651059/ARISE-SAI-1.5/"
                    "b.e21.BW.f09_g17.SSP245-G6-1p5K-SAI.0{ens}/"
                    "atm/proc/tseries/month_1/"
                ),
                "search_term": r"\.dst_[a-z][0-9]\.",
            },
        },
    },

    # UKESM1
    "UKESM1": {
        "base": "/glade/work/awells/air_quality/UKESM1/data",
        "scenarios": {
            # SSP2-4.5
            "SSP245_G6": {
                "dir_template": "{base}/SSP245_G6/",
                # UPDATE
                "search_term": r"du_mmr.*\.nc$",
            },

            # G6-1.5K-SAI
            "G6-1.5K": {
                "dir_template": "{base}/G6-1.5K/",
                # UPDATE
                "search_term": r"du_mmr.*\.nc$",
            },

            # Historical
            "hist": {
                "dir_template": "{base}/hist/",
                # UPDATE
                "search_term": r"du_mmr.*\.nc$",
            },
        },
    },
}


# return dir and search term for model/scenario
def get_path_config(model, scenario):
    try:
        entry = MODEL_PATH_CONFIG[model]
        scen = entry["scenarios"][scenario]
        return {
            "dir_template": scen["dir_template"].format(
                base=entry["base"],
                ens="{ens}"
            ),
            "search_term": scen["search_term"],
        }
    except KeyError:
        available_models = list(MODEL_PATH_CONFIG.keys())
        available_scenarios = (
            list(MODEL_PATH_CONFIG[model]["scenarios"].keys())
            if model in MODEL_PATH_CONFIG else []
        )
        raise ValueError(
            f"Config not found for model '{model}', scenario '{scenario}'.\n"
            f"Available models: {available_models}\n"
            f"Available scenarios for {model if model in MODEL_PATH_CONFIG else 'N/A'}: {available_scenarios}"
        )

# %%
def save_file_list_with_metadata(model, scenario, ens_num, file_list, DIR, filename):
    data = {
        "model": model,
        "scenario": scenario,
        "ensemble_number": ens_num,
        "generated_on": datetime.now().isoformat(),
        "files": file_list
    }
    file_path = os.path.join(DIR, filename)
    with open(file_path, "w") as f:
        json.dump(data, f, indent=2)

# %%
# === Scenario and path config ===
# Set to whatever scenario and model you want
# Function returns error if not recognised
model = "CESM2"
scenario = "hist"

config = get_scenario_config(model, scenario)
ensemble_members = config["ensemble_members"]

SAVE_DIR = f"/glade/work/awells/air_quality/{model}/pm25/file_paths/"

path_config = get_path_config(model, scenario)

for ens_num in ensemble_members:
    # Get file path
    dir_path = path_config["dir_template"].format(ens=f"{ens_num:02d}")
    pattern = re.compile(path_config["search_term"].format(ens=f"{ens_num:02d}"))

    # Find matching files using regex
    files = sorted([
        os.path.join(dir_path, f)
        for f in os.listdir(dir_path)
        if pattern.search(f)
    ])
    print(files[0])
    print(files[-1])

    # Save file list
    out_file = f"file_list_DU_{scenario}_{ens_num:02d}.json"
    save_file_list_with_metadata(model, scenario, ens_num, files, SAVE_DIR, out_file)

print("All processing complete.")
# Out:
# /glade/campaign/cesm/development/wawg/WACCM6-TSMLT-HIST/b.e21.BWHISTcmip6.f09_g17.CMIP6-historical-WACCM.1980_2014.001/atm/proc/tseries/month_1/b.e21.BWHISTcmip6.f09_g17.CMIP6-historical-WACCM.1980_2014.001.cam.h0.dst_a1.197801-199912.nc
# /glade/campaign/cesm/development/wawg/WACCM6-TSMLT-HIST/b.e21.BWHISTcmip6.f09_g17.CMIP6-historical-WACCM.1980_2014.001/atm/proc/tseries/month_1/b.e21.BWHISTcmip6.f09_g17.CMIP6-historical-WACCM.1980_2014.001.cam.h0.dst_c3.199912-201412.nc
# All processing complete.
