# %%
# Regrid BMR and ozone data to match population grid

# %%
import os
import xarray as xr
import regionmask
import matplotlib.pyplot as plt
import numpy as np

# %%
POP_DIR = "/glade/work/awells/air_quality/SSP_pop/SSP2/"
population = xr.open_dataarray(f"{POP_DIR}ssp2_total_regrid_2000-2100.nc")

pop_lat = population.lat.values
pop_lon = population.lon.values

# %%
BMR_DIR = "/glade/work/awells/air_quality/BMR/"
bmr = xr.open_dataarray(f"{BMR_DIR}GBD_BMR_Country_Mask_COPD_1990-2009.nc")

bmr_lat = bmr.lat.values
bmr_lon = bmr.lon.values

bmr_lat_mask = xr.ufuncs.logical_and(bmr_lat <= pop_lat.max(), bmr_lat >= pop_lat.min())
bmr_lon_mask = xr.ufuncs.logical_and(bmr_lon <= pop_lon.max(), bmr_lon >= pop_lon.min())

new_bmr = bmr.sel(lat=bmr_lat_mask)  # longitudes are the same
bmr_interp = new_bmr.interp(lat=population.lat, lon=population.lon, method="linear")

bmr_interp.to_netcdf(f"{BMR_DIR}GBD_BMR_Country_Mask_COPD_popgrid_1990-2009.nc")

# %%
# ensemble numbers
O3_DIR = "/glade/work/awells/air_quality/CESM/ozone/OSDMA8_BC/"
scenarios = ["ARISE", "SSP245"]

for scenario in scenarios:
    for ens_num in range(1, 11):
        print(f"Processing {scenario} ensemble number {ens_num:02d}")
        if scenario == "ARISE":
            dates = "2035-2069"
        elif scenario == "SSP245":
            dates = "2020-2069"
        o3 = xr.open_dataset(f"{O3_DIR}OSDMA8_BC_CESM2_{scenario}_{ens_num:02d}_{dates}.nc")

        o3_lat = o3.lat.values
        o3_lon = o3.lon.values

        o3_lat_mask = xr.ufuncs.logical_and(o3_lat <= pop_lat.max(), o3_lat >= pop_lat.min())
        o3_lon_mask = xr.ufuncs.logical_and(o3_lon <= pop_lon.max(), o3_lon >= pop_lon.min())

        new_o3 = o3.sel(lat=o3_lat_mask)  # longitudes are the same
        o3_interp = new_o3.interp(lat=population.lat, lon=population.lon, method="linear")

        print("Saving regridding o3")
        o3_interp.to_netcdf(f"{O3_DIR}OSDMA8_BC_popgrid_CESM2_{scenario}_{ens_num:02d}_{dates}.nc")

print("Processing complete")
# Out:
#  Processing ARISE ensemble number 01
# Saving regridding o3
#  Processing ARISE ensemble number 02
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x146f042acbc0>>
# Traceback (most recent call last):
#   File "/glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/coding/times.py:453, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     452 try:
# --> 453     dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     454 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/coding/times.py:363, in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     362 if not _is_standard_calendar(calendar):
# --> 363     raise OutOfBoundsDatetime(
#     364         f"Cannot decode times from a non-standard calendar, {calendar!r}, using "
#     365         "pandas."
#     366     )
#     368 # Work around pandas.to_timedelta issue with dtypes smaller than int64 and
#     369 # NumPy 2.0 by casting all int and uint data to int64 and uint64,
#     370 # respectively. See https://github.com/pandas-dev/pandas/issues/56996 for
#     371 # more details.
#
# OutOfBoundsDatetime: Cannot decode times from a non-standard calendar, 'noleap', using pandas.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 21
#      18 o3_lon_mask = xr.ufuncs.logical_and(o3_lon <= pop_lon.max(), o3_lon >= pop_lon.min())
#      20 new_o3 = o3.sel(lat=o3_lat_mask)  # longitudes are the same
# ---> 21 o3_interp = new_o3.interp(lat=population.lat, lon=population.lon, method="linear")
#      23 print("Saving regridding o3")
#      24 o3_interp.to_netcdf(f"{O3_DIR}OSDMA8_BC_CESM2_{scenario}_{ens_num:02d}_popgrid_{dates}.nc")
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/dataset.py:4176, in Dataset.interp(self, coords, method, assume_sorted, kwargs, method_non_numeric, **coords_kwargs)
#    4172 if name in indexers:
#    4173     continue
#    4175 use_indexers = (
# -> 4176     dask_indexers if is_duck_dask_array(var.data) else validated_indexers
#    4177 )
#    4179 dtype_kind = var.dtype.kind
#    4180 if dtype_kind in "uifc":
#    4181     # For normal number types do the interpolation:
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/variable.py:473, in Variable.data(self)
#     471     return self._data
#     472 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 473     return self._data.get_duck_array()
#     474 else:
#     475     return self.values
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:835, in MemoryCachedArray.get_duck_array(self)
#     834 def get_duck_array(self):
# --> 835     self._ensure_cached()
#     836     return self.array.get_duck_array()
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:832, in MemoryCachedArray._ensure_cached(self)
#     831 def _ensure_cached(self):
# --> 832     self.array = as_indexable(self.array.get_duck_array())
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:789, in CopyOnWriteArray.get_duck_array(self)
#     788 def get_duck_array(self):
# --> 789     return self.array.get_duck_array()
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/core/indexing.py:659, in LazilyIndexedArray.get_duck_array(self)
#     654 # self.array[self.key] is now a numpy array when
#     655 # self.array is a BackendArray subclass
#     656 # and self.key is BasicIndexer((slice(None, None, None),))
#     657 # so we need the explicit check for ExplicitlyIndexed
#     658 if isinstance(array, ExplicitlyIndexed):
# --> 659     array = array.get_duck_array()
#     660 return _wrap_numpy_scalars(array)
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/coding/variables.py:81, in _ElementwiseFunctionArray.get_duck_array(self)
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/coding/times.py:455, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     453     dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     454 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
# --> 455     dates = _decode_datetime_with_cftime(
#     456         flat_num_dates.astype(float), units, calendar
#     457     )
#     458     # retrieve cftype
#     459     dates_min = dates[np.nanargmin(num_dates)]
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/xarray/coding/times.py:329, in _decode_datetime_with_cftime(num_dates, units, calendar)
#     326     cftime = attempt_import("cftime")
#     327 if num_dates.size > 0:
#     328     return np.asarray(
# --> 329         cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#     330     )
#     331 else:
#     332     return np.array([], dtype=object)
#
# File src/cftime/_cftime.pyx:627, in cftime._cftime.num2date()
#
# File src/cftime/_cftime.pyx:434, in cftime._cftime.cast_to_int()
#
# File /glade/work/awells/conda-envs/my-env/lib/python3.12/site-packages/numpy/core/multiarray.py:346, in where(condition, x, y)
#     256     """
#     257     inner(a, b, /)
#     258
#    (...)
#     341
#     342     """
#     343     return (a, b)
# --> 346 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     347 def where(condition, x=None, y=None):
#     348     """
#     349     where(condition, [x, y], /)
#     350
#    (...)
#     416            [ 0,  3, -1]])
#     417     """
#     418     return (condition, x, y)
#
# KeyboardInterrupt:
